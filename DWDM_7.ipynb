# %% [markdown]
# <a href="https://colab.research.google.com/github/karthi234231/DataMining/blob/main/DWDM_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/MELBOURNE_HOUSE_PRICES_LESS.csv', header=None)
data.head()
data.drop(columns=[0], inplace=True, axis=1)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
onehot_data = pd.get_dummies(data)
frequent_itemsets = apriori(onehot_data, min_support=0.1, use_colnames=True)

# %%
association_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
frequent_itemsets
# Out:
#      support                             itemsets
# 0   0.210206                                (2_2)
# 1   0.443482                                (2_3)
# 2   0.249857                                (2_4)
# 3   0.714855                                (3_h)
# 4   0.100200                                (3_t)
# 5   0.184930                                (3_u)
# 6   0.155338                               (5_PI)
# 7   0.540477                                (5_S)
# 8   0.141470                               (5_SP)
# 9   0.109387                            (6_Barry)
# 10  0.164953             (9_Eastern Metropolitan)
# 11  0.266264            (9_Northern Metropolitan)
# 12  0.278608            (9_Southern Metropolitan)
# 13  0.185913             (9_Western Metropolitan)
# 14  0.114496                           (3_u, 2_2)
# 15  0.116781                           (5_S, 2_2)
# 16  0.349343                           (2_3, 3_h)
# 17  0.251825                           (2_3, 5_S)
# ...

# %%
association_rules
# Out:
#                        antecedents                     consequents  \
# 0                            (3_u)                           (2_2)
# 1                            (2_2)                           (3_u)
# 2                            (5_S)                           (2_2)
# 3                            (2_2)                           (5_S)
# 4                            (2_3)                           (3_h)
# 5                            (3_h)                           (2_3)
# 6                            (2_3)                           (5_S)
# 7                            (5_S)                           (2_3)
# 8        (9_Northern Metropolitan)                           (2_3)
# 9                            (2_3)       (9_Northern Metropolitan)
# 10                           (3_h)                           (2_4)
# 11                           (2_4)                           (3_h)
# 12                           (3_h)                           (5_S)
# ...
